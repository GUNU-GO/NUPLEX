# %%
import pandas as pd
import numpy as np
from scipy import interpolate
import matplotlib.pyplot as plt
from scipy.signal import savgol_filter

e = 1.6e-19
m = 9.1e-31

# %%
data = pd.read_excel('C:/Users/Administrator/Dropbox/PRL/Python_Projects/IV_characteristic/Drift_Velocity.xlsx')
data
# Out:
#             B   n          n_Baseline              n_Low   \
# 0    31.80456 -12  198588000000000000  137886000000000000
# 1    42.40607 -10  295470000000000000  171855000000000000
# 2    53.00758  -8  379890000000000000  215070000000000000
# 3    63.60910  -6  472350000000000000  253260000000000000
# 4    74.21061  -4  540690000000000000  285420000000000000
# 5    84.81213  -2  572850000000000000  305520000000000000
# 6    95.41365   0  576870000000000000  315570000000000000
# 7   106.01516   2  605010000000000000  329640000000000000
# 8   116.61668   4  586920000000000000  339690000000000000
# 9   127.21819   6  556770000000000000  351750000000000000
# 10  137.81971   8  520590000000000000  339690000000000000
# 11  148.42123  10  452250000000000000  307530000000000000
# 12  159.02274  12  373860000000000000  285420000000000000
# 13        NaN  14  295470000000000000  273360000000000000
# 14        NaN  16  245220000000000000  253260000000000000
# ...

# %%
position = np.array(data['n'])
B_list = np.array(data['B'])[0:-5]
n_base = np.array(data['n_Baseline'])
n_low = np.array(data['n_Low '])
n_high = np.array(data['n_High'])
T_base = np.array(data['T_Baseline'])
T_low = np.array(data['T_Low '])
T_high = np.array(data['T_High'])
V_base = np.array(data['V_Baseline'])
V_low = np.array(data['V_Low '])
V_high = np.array(data['V_High'])
print(B_list)
# Out:
# [ 31.80456  42.40607  53.00758  63.6091   74.21061  84.81213  95.41365
#  106.01516 116.61668 127.21819 137.81971 148.42123 159.02274]
